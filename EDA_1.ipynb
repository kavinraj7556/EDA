# %%
import pandas as pd 
df=pd.read_csv(r"C:\Users\KAVIN D\Downloads\EV_Dataset.csv")
df.head()
# Out:
#      Year Month_Name      Date           State         Vehicle_Class  \
# 0  2014.0        jan  1/1/2014  Andhra Pradesh       ADAPTED VEHICLE
# 1  2014.0        jan  1/1/2014  Andhra Pradesh  AGRICULTURAL TRACTOR
# 2  2014.0        jan  1/1/2014  Andhra Pradesh             AMBULANCE
# 3  2014.0        jan  1/1/2014  Andhra Pradesh   ARTICULATED VEHICLE
# 4  2014.0        jan  1/1/2014  Andhra Pradesh                   BUS
#
#   Vehicle_Category Vehicle_Type  EV_Sales_Quantity
# 0           Others       Others                0.0
# 1           Others       Others                0.0
# 2           Others       Others                0.0
# 3           Others       Others                0.0
# 4              Bus          Bus                0.0

# %%
df.isnull().sum()
# Out:
# Year                 0
# Month_Name           0
# Date                 0
# State                0
# Vehicle_Class        0
# Vehicle_Category     0
# Vehicle_Type         0
# EV_Sales_Quantity    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Year', 'Month_Name', 'Date', 'State', 'Vehicle_Class',
#        'Vehicle_Category', 'Vehicle_Type', 'EV_Sales_Quantity'],
#       dtype='object')

# %%
df[["State"]]
# Out:
#                           State
# 0                Andhra Pradesh
# 1                Andhra Pradesh
# 2                Andhra Pradesh
# 3                Andhra Pradesh
# 4                Andhra Pradesh
# ...                         ...
# 96840  Andaman & Nicobar Island
# 96841  Andaman & Nicobar Island
# 96842  Andaman & Nicobar Island
# 96843  Andaman & Nicobar Island
# 96844  Andaman & Nicobar Island
#
# [96845 rows x 1 columns]

# %%
import pandas as pd
import numpy as np
df = df.replace({"State": {"Andhra Pradesh": np.nan}})

# %%
df.isnull().sum()
# Out:
# Year                    0
# Month_Name              0
# Date                    0
# State                3457
# Vehicle_Class           0
# Vehicle_Category        0
# Vehicle_Type            0
# EV_Sales_Quantity       0
# dtype: int64

# %%
df.head()
# Out:
#      Year Month_Name      Date State         Vehicle_Class Vehicle_Category  \
# 0  2014.0        jan  1/1/2014   NaN       ADAPTED VEHICLE           Others
# 1  2014.0        jan  1/1/2014   NaN  AGRICULTURAL TRACTOR           Others
# 2  2014.0        jan  1/1/2014   NaN             AMBULANCE           Others
# 3  2014.0        jan  1/1/2014   NaN   ARTICULATED VEHICLE           Others
# 4  2014.0        jan  1/1/2014   NaN                   BUS              Bus
#
#   Vehicle_Type  EV_Sales_Quantity
# 0       Others                0.0
# 1       Others                0.0
# 2       Others                0.0
# 3       Others                0.0
# 4          Bus                0.0

# %%
df.tail()
# Out:
#          Year Month_Name       Date                     State  \
# 96840  2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 96841  2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 96842  2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 96843  2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 96844  2023.0        dec  12/1/2023  Andaman & Nicobar Island
#
#                            Vehicle_Class Vehicle_Category Vehicle_Type  \
# 96840                          MOTOR CAR       4-Wheelers  4W_Personal
# 96841  MOTOR CYCLE/SCOOTER-USED FOR HIRE       2-Wheelers    2W_Shared
# 96842                           OMNI BUS              Bus          Bus
# 96843              THREE WHEELER (GOODS)       3-Wheelers     3W_Goods
# 96844          THREE WHEELER (PASSENGER)       3-Wheelers    3W_Shared
#
#        EV_Sales_Quantity
# 96840                1.0
# 96841                5.0
# 96842                0.0
# 96843                0.0
# 96844                0.0

# %%
df.describe()
# Out:
#                Year  EV_Sales_Quantity
# count  96845.000000       96845.000000
# mean    2018.622768          37.108896
# std        2.895581         431.566675
# min     2014.000000           0.000000
# 25%     2016.000000           0.000000
# 50%     2019.000000           0.000000
# 75%     2021.000000           0.000000
# max     2024.000000       20584.000000

# %%
df.shape
# Out:
# (96845, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96845 entries, 0 to 96844
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               96845 non-null  float64
#  1   Month_Name         96845 non-null  object
#  2   Date               96845 non-null  object
#  3   State              93388 non-null  object
#  4   Vehicle_Class      96845 non-null  object
#  5   Vehicle_Category   96845 non-null  object
#  6   Vehicle_Type       96845 non-null  object
#  7   EV_Sales_Quantity  96845 non-null  float64
# dtypes: float64(2), object(6)
# memory usage: 5.9+ MB

# %%
df[(df["Vehicle_Category"] == "Others") & (df["Vehicle_Type"] == "Others")]
# Out:
#          Year Month_Name       Date                     State  \
# 0      2014.0        jan   1/1/2014                       NaN
# 1      2014.0        jan   1/1/2014                       NaN
# 2      2014.0        jan   1/1/2014                       NaN
# 3      2014.0        jan   1/1/2014                       NaN
# 5      2014.0        jan   1/1/2014                       NaN
# ...       ...        ...        ...                       ...
# 96825  2023.0        dec  12/1/2023                       Goa
# 96829  2023.0        dec  12/1/2023                       Goa
# 96834  2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 96835  2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 96836  2023.0        dec  12/1/2023  Andaman & Nicobar Island
#
#                         Vehicle_Class Vehicle_Category Vehicle_Type  \
# 0                     ADAPTED VEHICLE           Others       Others
# 1                AGRICULTURAL TRACTOR           Others       Others
# ...

# %%
df[(df["Vehicle_Category"] == "Others")&(df["Vehicle_Type"] == "Others")&(df["Month_Name"] == "jan")]
# Out:
#         Year Month_Name      Date      State                  Vehicle_Class  \
# 0     2014.0        jan  1/1/2014        NaN                ADAPTED VEHICLE
# 1     2014.0        jan  1/1/2014        NaN           AGRICULTURAL TRACTOR
# 2     2014.0        jan  1/1/2014        NaN                      AMBULANCE
# 3     2014.0        jan  1/1/2014        NaN            ARTICULATED VEHICLE
# 5     2014.0        jan  1/1/2014        NaN                       CASH VAN
# ...      ...        ...       ...        ...                            ...
# 8848  2024.0        jan  1/1/2024  Karnataka           TRACTOR (COMMERCIAL)
# 8849  2024.0        jan  1/1/2024  Karnataka         TRAILER (AGRICULTURAL)
# 8850  2024.0        jan  1/1/2024  Karnataka           TRAILER (COMMERCIAL)
# 8851  2024.0        jan  1/1/2024  Karnataka  VEHICLE FITTED WITH GENERATOR
# 8852  2024.0        jan  1/1/2024  Karnataka        VEHICLE FITTED WITH RIG
#
#      Vehicle_Category Vehicle_Type  EV_Sales_Quantity
# ...

# %%
df.loc[(df["Vehicle_Category"] == "Others") &
       (df["Vehicle_Type"] == "Others") &
       (df["Month_Name"] == "jan") ,"State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                    0
# Month_Name              0
# Date                    0
# State                3251
# Vehicle_Class           0
# Vehicle_Category        0
# Vehicle_Type            0
# EV_Sales_Quantity       0
# dtype: int64

# %%
df[df["State"].isna()].head(50)
# Out:
#         Year Month_Name      Date State                  Vehicle_Class  \
# 4     2014.0        jan  1/1/2014   NaN                            BUS
# 7     2014.0        jan  1/1/2014   NaN    EDUCATIONAL INSTITUTION BUS
# 13    2014.0        jan  1/1/2014   NaN                M-CYCLE/SCOOTER
# 14    2014.0        jan  1/1/2014   NaN                      MOTOR CAB
# 15    2014.0        jan  1/1/2014   NaN                      MOTOR CAR
# 16    2014.0        jan  1/1/2014   NaN                       OMNI BUS
# 19    2014.0        jan  1/1/2014   NaN      THREE WHEELER (PASSENGER)
# 765   2015.0        jan  1/1/2015   NaN                            BUS
# 768   2015.0        jan  1/1/2015   NaN    EDUCATIONAL INSTITUTION BUS
# 774   2015.0        jan  1/1/2015   NaN                M-CYCLE/SCOOTER
# 775   2015.0        jan  1/1/2015   NaN  M-CYCLE/SCOOTER-WITH SIDE CAR
# 776   2015.0        jan  1/1/2015   NaN                      MOTOR CAB
# ...

# %%
df[(df["Month_Name"] == "jan") & (df["Year"].isin([2014.0,2015.0]))]
# Out:
#         Year Month_Name      Date      State                Vehicle_Class  \
# 0     2014.0        jan  1/1/2014  Karnataka              ADAPTED VEHICLE
# 1     2014.0        jan  1/1/2014  Karnataka         AGRICULTURAL TRACTOR
# 2     2014.0        jan  1/1/2014  Karnataka                    AMBULANCE
# 3     2014.0        jan  1/1/2014  Karnataka          ARTICULATED VEHICLE
# 4     2014.0        jan  1/1/2014        NaN                          BUS
# ...      ...        ...       ...        ...                          ...
# 1495  2015.0        jan  1/1/2015    Manipur                    MOTOR CAB
# 1496  2015.0        jan  1/1/2015    Manipur                    MOTOR CAR
# 1497  2015.0        jan  1/1/2015    Manipur  MOTORISED CYCLE (CC > 25CC)
# 1498  2015.0        jan  1/1/2015    Manipur                     OMNI BUS
# 1499  2015.0        jan  1/1/2015    Manipur    THREE WHEELER (PASSENGER)
#
#      Vehicle_Category Vehicle_Type  EV_Sales_Quantity
# ...

# %%
df.loc[(df["Month_Name"] == "jan") &
       (df["Year"] == 2014.0),"State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                    0
# Month_Name              0
# Date                    0
# State                3244
# Vehicle_Class           0
# Vehicle_Category        0
# Vehicle_Type            0
# EV_Sales_Quantity       0
# dtype: int64

# %%
df.loc[(df["Month_Name"] == "jan") &
       (df["Year"] == 2015.0),"State"] = "Manipur"

# %%
df.isnull().sum()
# Out:
# Year                    0
# Month_Name              0
# Date                    0
# State                3236
# Vehicle_Class           0
# Vehicle_Category        0
# Vehicle_Type            0
# EV_Sales_Quantity       0
# dtype: int64

# %%
df[df["State"].isna()].head(50)
# Out:
#         Year Month_Name      Date State                  Vehicle_Class  \
# 1504  2016.0        jan  1/1/2016   NaN                            BUS
# 1508  2016.0        jan  1/1/2016   NaN    EDUCATIONAL INSTITUTION BUS
# 1514  2016.0        jan  1/1/2016   NaN                M-CYCLE/SCOOTER
# 1516  2016.0        jan  1/1/2016   NaN                      MOTOR CAB
# 1517  2016.0        jan  1/1/2016   NaN                      MOTOR CAR
# 1518  2016.0        jan  1/1/2016   NaN                       OMNI BUS
# 1522  2016.0        jan  1/1/2016   NaN      THREE WHEELER (PASSENGER)
# 2290  2017.0        jan  1/1/2017   NaN                            BUS
# 2294  2017.0        jan  1/1/2017   NaN    EDUCATIONAL INSTITUTION BUS
# 2301  2017.0        jan  1/1/2017   NaN                M-CYCLE/SCOOTER
# 2302  2017.0        jan  1/1/2017   NaN                      MOTOR CAB
# 2303  2017.0        jan  1/1/2017   NaN                      MOTOR CAR
# ...

# %%
df[(df["Month_Name"] == "jan") & (df["Year"].isin([2016.0,2017.0,2018.0,2019.0,2020.0]))]
# Out:
#         Year Month_Name      Date        State                  Vehicle_Class  \
# 1500  2016.0        jan  1/1/2016    Karnataka                ADAPTED VEHICLE
# 1501  2016.0        jan  1/1/2016    Karnataka           AGRICULTURAL TRACTOR
# 1502  2016.0        jan  1/1/2016    Karnataka                      AMBULANCE
# 1503  2016.0        jan  1/1/2016    Karnataka            ARTICULATED VEHICLE
# 1504  2016.0        jan  1/1/2016          NaN                            BUS
# ...      ...        ...       ...          ...                            ...
# 5587  2020.0        jan  1/1/2020  West Bengal          THREE WHEELER (GOODS)
# 5588  2020.0        jan  1/1/2020  West Bengal      THREE WHEELER (PASSENGER)
# 5589  2020.0        jan  1/1/2020    Karnataka           TRACTOR (COMMERCIAL)
# 5590  2020.0        jan  1/1/2020    Karnataka           TRAILER (COMMERCIAL)
# 5591  2020.0        jan  1/1/2020    Karnataka  VEHICLE FITTED WITH GENERATOR
#
# ...

# %%
df.loc[(df["Month_Name"] == "jan") &
       (df["Year"] == 2016.0),"State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                    0
# Month_Name              0
# Date                    0
# State                3229
# Vehicle_Class           0
# Vehicle_Category        0
# Vehicle_Type            0
# EV_Sales_Quantity       0
# dtype: int64

# %%
df.loc[(df["Month_Name"] == "jan") &
       (df["Year"] == 2020.0),"State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                    0
# Month_Name              0
# Date                    0
# State                3218
# Vehicle_Class           0
# Vehicle_Category        0
# Vehicle_Type            0
# EV_Sales_Quantity       0
# dtype: int64

# %%
df[(df["Month_Name"] == "jan") & (df["Year"].isin([2017.0,2018.0,2019.0]))]
# Out:
#         Year Month_Name      Date              State  \
# 2232  2017.0        jan  1/1/2017          Karnataka
# 2233  2017.0        jan  1/1/2017          Karnataka
# 2234  2017.0        jan  1/1/2017          Karnataka
# 2235  2017.0        jan  1/1/2017  Arunachal Pradesh
# 2236  2017.0        jan  1/1/2017          Karnataka
# ...      ...        ...       ...                ...
# 4715  2019.0        jan  1/1/2019        West Bengal
# 4716  2019.0        jan  1/1/2019          Karnataka
# 4717  2019.0        jan  1/1/2019          Karnataka
# 4718  2019.0        jan  1/1/2019          Karnataka
# 4719  2019.0        jan  1/1/2019          Karnataka
#
#                                     Vehicle_Class Vehicle_Category  \
# 2232                         AGRICULTURAL TRACTOR           Others
# 2233                                    AMBULANCE           Others
# 2234                          ARTICULATED VEHICLE           Others
# ...

# %%
df.loc[(df["Month_Name"] == "jan") &
       (df["Year"].isin([2017.0,2019.0])),"State"] = "Karnataka"

# %%
df[(df["Month_Name"] == "jan") & (df["Year"].isin([2018.0]))]
# Out:
#         Year Month_Name      Date              State  \
# 3014  2018.0        jan  1/1/2018          Karnataka
# 3015  2018.0        jan  1/1/2018          Karnataka
# 3016  2018.0        jan  1/1/2018          Karnataka
# 3017  2018.0        jan  1/1/2018          Karnataka
# 3018  2018.0        jan  1/1/2018  Arunachal Pradesh
# ...      ...        ...       ...                ...
# 3860  2018.0        jan  1/1/2018  Jammu and Kashmir
# 3861  2018.0        jan  1/1/2018          Karnataka
# 3862  2018.0        jan  1/1/2018  Jammu and Kashmir
# 3863  2018.0        jan  1/1/2018  Jammu and Kashmir
# 3864  2018.0        jan  1/1/2018          Karnataka
#
#                   Vehicle_Class Vehicle_Category Vehicle_Type  \
# 3014            ADAPTED VEHICLE           Others       Others
# 3015       AGRICULTURAL TRACTOR           Others       Others
# 3016                  AMBULANCE           Others       Others
# 3017        ARTICULATED VEHICLE           Others       Others
# ...

# %%
df.isnull().sum()
# Out:
# Year                    0
# Month_Name              0
# Date                    0
# State                3201
# Vehicle_Class           0
# Vehicle_Category        0
# Vehicle_Type            0
# EV_Sales_Quantity       0
# dtype: int64

# %%
df[df["State"].isna()].head(40)
# Out:
#         Year Month_Name      Date State                      Vehicle_Class  \
# 3073  2018.0        jan  1/1/2018   NaN                                BUS
# 3077  2018.0        jan  1/1/2018   NaN        EDUCATIONAL INSTITUTION BUS
# 3083  2018.0        jan  1/1/2018   NaN                    M-CYCLE/SCOOTER
# 3084  2018.0        jan  1/1/2018   NaN      M-CYCLE/SCOOTER-WITH SIDE CAR
# 3085  2018.0        jan  1/1/2018   NaN                          MOTOR CAB
# 3086  2018.0        jan  1/1/2018   NaN                          MOTOR CAR
# 3087  2018.0        jan  1/1/2018   NaN                           OMNI BUS
# 3091  2018.0        jan  1/1/2018   NaN          THREE WHEELER (PASSENGER)
# 5652  2021.0        jan  1/1/2021   NaN                                BUS
# 5656  2021.0        jan  1/1/2021   NaN        EDUCATIONAL INSTITUTION BUS
# 5657  2021.0        jan  1/1/2021   NaN                      E-RICKSHAW(P)
# ...

# %%
df.loc[(df["Month_Name"] == "jan") &
       (df["Year"].isin([2018.0,2020.0,2021.0,2022.0,2023.0,2024.0])),"State"] = "Karnataka"

# %%
df.isnull().sum()
# Out:
# Year                    0
# Month_Name              0
# Date                    0
# State                3144
# Vehicle_Class           0
# Vehicle_Category        0
# Vehicle_Type            0
# EV_Sales_Quantity       0
# dtype: int64

# %%
df[df["State"].isna()].head(40)
# Out:
#         Year Month_Name      Date State                   Vehicle_Class  \
# 8853  2014.0        feb  2/1/2014   NaN            AGRICULTURAL TRACTOR
# 8854  2014.0        feb  2/1/2014   NaN                       AMBULANCE
# 8855  2014.0        feb  2/1/2014   NaN             ARTICULATED VEHICLE
# 8856  2014.0        feb  2/1/2014   NaN                             BUS
# 8857  2014.0        feb  2/1/2014   NaN            CAMPER VAN / TRAILER
# 8858  2014.0        feb  2/1/2014   NaN                        CASH VAN
# 8859  2014.0        feb  2/1/2014   NaN           CRANE MOUNTED VEHICLE
# 8860  2014.0        feb  2/1/2014   NaN     EDUCATIONAL INSTITUTION BUS
# 8861  2014.0        feb  2/1/2014   NaN                    FIRE TENDERS
# 8862  2014.0        feb  2/1/2014   NaN                   GOODS CARRIER
# 8863  2014.0        feb  2/1/2014   NaN                       HARVESTER
# 8864  2014.0        feb  2/1/2014   NaN                        MAXI CAB
# ...

# %%
df[(df["Month_Name"] == "feb") & (df["Year"].isin([2018.0]))]
# Out:
#          Year Month_Name      Date              State  \
# 11936  2018.0        feb  2/1/2018  Arunachal Pradesh
# 11937  2018.0        feb  2/1/2018  Arunachal Pradesh
# 11938  2018.0        feb  2/1/2018  Arunachal Pradesh
# 11939  2018.0        feb  2/1/2018  Arunachal Pradesh
# 11940  2018.0        feb  2/1/2018  Arunachal Pradesh
# ...       ...        ...       ...                ...
# 12781  2018.0        feb  2/1/2018  Jammu and Kashmir
# 12782  2018.0        feb  2/1/2018  Jammu and Kashmir
# 12783  2018.0        feb  2/1/2018  Jammu and Kashmir
# 12784  2018.0        feb  2/1/2018  Jammu and Kashmir
# 12785  2018.0        feb  2/1/2018  Jammu and Kashmir
#
#                    Vehicle_Class Vehicle_Category Vehicle_Type  \
# 11936            ADAPTED VEHICLE           Others       Others
# 11937       AGRICULTURAL TRACTOR           Others       Others
# 11938                  AMBULANCE           Others       Others
# ...

# %%
df[df["State"].isna()].head(100)
# Out:
#          Year Month_Name      Date State                  Vehicle_Class  \
# 8853   2014.0        feb  2/1/2014   NaN           AGRICULTURAL TRACTOR
# 8854   2014.0        feb  2/1/2014   NaN                      AMBULANCE
# 8855   2014.0        feb  2/1/2014   NaN            ARTICULATED VEHICLE
# 8856   2014.0        feb  2/1/2014   NaN                            BUS
# 8857   2014.0        feb  2/1/2014   NaN           CAMPER VAN / TRAILER
# ...       ...        ...       ...   ...                            ...
# 11218  2017.0        feb  2/1/2017   NaN                M-CYCLE/SCOOTER
# 11219  2017.0        feb  2/1/2017   NaN  M-CYCLE/SCOOTER-WITH SIDE CAR
# 11220  2017.0        feb  2/1/2017   NaN                      MOTOR CAB
# 11221  2017.0        feb  2/1/2017   NaN                      MOTOR CAR
# 11222  2017.0        feb  2/1/2017   NaN                       OMNI BUS
#
#       Vehicle_Category Vehicle_Type  EV_Sales_Quantity
# ...

# %%
df.loc[(df["Month_Name"] == "feb") &
       (df["Year"].isin([2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0,2021.0,2022.0,2023.0,2024.0])),"State"] = "Arunachal Pradesh"

# %%
df.isnull().sum()
# Out:
# Year                    0
# Month_Name              0
# Date                    0
# State                2857
# Vehicle_Class           0
# Vehicle_Category        0
# Vehicle_Type            0
# EV_Sales_Quantity       0
# dtype: int64

# %%
df[df["State"].isna()].head(100)
# Out:
#          Year Month_Name      Date State           Vehicle_Class  \
# 16925  2014.0        mar  3/1/2014   NaN    AGRICULTURAL TRACTOR
# 16926  2014.0        mar  3/1/2014   NaN               AMBULANCE
# 16927  2014.0        mar  3/1/2014   NaN     ARTICULATED VEHICLE
# 16928  2014.0        mar  3/1/2014   NaN                     BUS
# 16929  2014.0        mar  3/1/2014   NaN   CRANE MOUNTED VEHICLE
# ...       ...        ...       ...   ...                     ...
# 19279  2017.0        mar  3/1/2017   NaN  EXCAVATOR (COMMERCIAL)
# 19280  2017.0        mar  3/1/2017   NaN            FIRE TENDERS
# 19281  2017.0        mar  3/1/2017   NaN               FORK LIFT
# 19282  2017.0        mar  3/1/2017   NaN           GOODS CARRIER
# 19283  2017.0        mar  3/1/2017   NaN               HARVESTER
#
#       Vehicle_Category Vehicle_Type  EV_Sales_Quantity
# 16925           Others       Others                0.0
# 16926           Others       Others                0.0
# ...

# %%
df[(df["Month_Name"] == "mar") ]
# Out:
#          Year Month_Name      Date        State  \
# 16925  2014.0        mar  3/1/2014          NaN
# 16926  2014.0        mar  3/1/2014          NaN
# 16927  2014.0        mar  3/1/2014          NaN
# 16928  2014.0        mar  3/1/2014          NaN
# 16929  2014.0        mar  3/1/2014          NaN
# ...       ...        ...       ...          ...
# 25355  2023.0        mar  3/1/2023  West Bengal
# 25356  2023.0        mar  3/1/2023  West Bengal
# 25357  2023.0        mar  3/1/2023  West Bengal
# 25358  2023.0        mar  3/1/2023  West Bengal
# 25359  2023.0        mar  3/1/2023  West Bengal
#
#                        Vehicle_Class Vehicle_Category Vehicle_Type  \
# 16925           AGRICULTURAL TRACTOR           Others       Others
# 16926                      AMBULANCE           Others       Others
# 16927            ARTICULATED VEHICLE           Others       Others
# 16928                            BUS              Bus          Bus
# ...

# %%
df.loc[(df["Month_Name"] == "mar") &
       (df["Year"].isin([2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0,2021.0,2022.0,2023.0,2024.0])),"State"] = "West Bengal"

# %%
df.isnull().sum()
# Out:
# Year                    0
# Month_Name              0
# Date                    0
# State                2552
# Vehicle_Class           0
# Vehicle_Category        0
# Vehicle_Type            0
# EV_Sales_Quantity       0
# dtype: int64

# %%
df[(df["Month_Name"] == "apr") ]
# Out:
#          Year Month_Name      Date        State  \
# 25360  2014.0        apr  4/1/2014          NaN
# 25361  2014.0        apr  4/1/2014          NaN
# 25362  2014.0        apr  4/1/2014          NaN
# 25363  2014.0        apr  4/1/2014          NaN
# 25364  2014.0        apr  4/1/2014          NaN
# ...       ...        ...       ...          ...
# 33272  2023.0        apr  4/1/2023  West Bengal
# 33273  2023.0        apr  4/1/2023  West Bengal
# 33274  2023.0        apr  4/1/2023  West Bengal
# 33275  2023.0        apr  4/1/2023  West Bengal
# 33276  2023.0        apr  4/1/2023  West Bengal
#
#                        Vehicle_Class Vehicle_Category Vehicle_Type  \
# 25360                ADAPTED VEHICLE           Others       Others
# 25361           AGRICULTURAL TRACTOR           Others       Others
# 25362                      AMBULANCE           Others       Others
# 25363            ARTICULATED VEHICLE           Others       Others
# ...

# %%
df.loc[(df["Month_Name"] == "apr") &
       (df["Year"].isin([2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0,2021.0,2022.0,2023.0,2024.0])),"State"] = "West Bengal"

# %%
df.isnull().sum()
# Out:
# Year                    0
# Month_Name              0
# Date                    0
# State                2262
# Vehicle_Class           0
# Vehicle_Category        0
# Vehicle_Type            0
# EV_Sales_Quantity       0
# dtype: int64

# %%
df[df["State"].isna()].head(100)
# Out:
#          Year Month_Name      Date State                  Vehicle_Class  \
# 33284  2014.0        may  5/1/2014   NaN           AGRICULTURAL TRACTOR
# 33285  2014.0        may  5/1/2014   NaN                      AMBULANCE
# 33286  2014.0        may  5/1/2014   NaN            ARTICULATED VEHICLE
# 33287  2014.0        may  5/1/2014   NaN                            BUS
# 33288  2014.0        may  5/1/2014   NaN                       CASH VAN
# ...       ...        ...       ...   ...                            ...
# 35607  2017.0        may  5/1/2017   NaN  M-CYCLE/SCOOTER-WITH SIDE CAR
# 35608  2017.0        may  5/1/2017   NaN                  MOBILE CLINIC
# 35609  2017.0        may  5/1/2017   NaN                      MOTOR CAB
# 35610  2017.0        may  5/1/2017   NaN                      MOTOR CAR
# 35611  2017.0        may  5/1/2017   NaN                       OMNI BUS
#
#       Vehicle_Category Vehicle_Type  EV_Sales_Quantity
# ...

# %%
df[(df["Month_Name"] == "may") ]
# Out:
#          Year Month_Name      Date                     State  \
# 33277  2014.0        may  5/1/2014  Andaman & Nicobar Island
# 33278  2014.0        may  5/1/2014  Andaman & Nicobar Island
# 33279  2014.0        may  5/1/2014  Andaman & Nicobar Island
# 33280  2014.0        may  5/1/2014  Andaman & Nicobar Island
# 33281  2014.0        may  5/1/2014  Andaman & Nicobar Island
# ...       ...        ...       ...                       ...
# 40894  2023.0        may  5/1/2023               West Bengal
# 40895  2023.0        may  5/1/2023               West Bengal
# 40896  2023.0        may  5/1/2023               West Bengal
# 40897  2023.0        may  5/1/2023               West Bengal
# 40898  2023.0        may  5/1/2023               West Bengal
#
#                        Vehicle_Class Vehicle_Category Vehicle_Type  \
# 33277                            BUS              Bus          Bus
# 33278                  GOODS CARRIER           Others       Others
# ...

# %%
df.loc[(df["Month_Name"] == "may") &
       (df["Year"].isin([2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0,2021.0,2022.0,2023.0,2024.0])),"State"] = "Andaman & Nicobar Island"

# %%
df.isnull().sum()
# Out:
# Year                    0
# Month_Name              0
# Date                    0
# State                1985
# Vehicle_Class           0
# Vehicle_Category        0
# Vehicle_Type            0
# EV_Sales_Quantity       0
# dtype: int64

# %%
df[(df["Month_Name"] == "jun") ]
# Out:
#          Year Month_Name      Date        State  \
# 40899  2014.0        jun  6/1/2014          NaN
# 40900  2014.0        jun  6/1/2014          NaN
# 40901  2014.0        jun  6/1/2014          NaN
# 40902  2014.0        jun  6/1/2014          NaN
# 40903  2014.0        jun  6/1/2014          NaN
# ...       ...        ...       ...          ...
# 48746  2023.0        jun  6/1/2023  West Bengal
# 48747  2023.0        jun  6/1/2023  West Bengal
# 48748  2023.0        jun  6/1/2023  West Bengal
# 48749  2023.0        jun  6/1/2023  West Bengal
# 48750  2023.0        jun  6/1/2023  West Bengal
#
#                         Vehicle_Class Vehicle_Category Vehicle_Type  \
# 40899            AGRICULTURAL TRACTOR           Others       Others
# 40900                       AMBULANCE           Others       Others
# 40901             ARTICULATED VEHICLE           Others       Others
# 40902                             BUS              Bus          Bus
# ...

# %%
df.loc[(df["Month_Name"] == "jun") &
       (df["Year"].isin([2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0,2021.0,2022.0,2023.0,2024.0])),"State"] = "West Bengal"

# %%
df.isnull().sum()
# Out:
# Year                    0
# Month_Name              0
# Date                    0
# State                1712
# Vehicle_Class           0
# Vehicle_Category        0
# Vehicle_Type            0
# EV_Sales_Quantity       0
# dtype: int64

# %%
df[(df["Month_Name"] == "jul") ]
# Out:
#          Year Month_Name      Date                     State  \
# 48751  2014.0        jul  7/1/2014                       NaN
# 48752  2014.0        jul  7/1/2014                       NaN
# 48753  2014.0        jul  7/1/2014                       NaN
# 48754  2014.0        jul  7/1/2014                       NaN
# 48755  2014.0        jul  7/1/2014                       NaN
# ...       ...        ...       ...                       ...
# 56729  2023.0        jul  7/1/2023  Andaman & Nicobar Island
# 56730  2023.0        jul  7/1/2023  Andaman & Nicobar Island
# 56731  2023.0        jul  7/1/2023  Andaman & Nicobar Island
# 56732  2023.0        jul  7/1/2023  Andaman & Nicobar Island
# 56733  2023.0        jul  7/1/2023  Andaman & Nicobar Island
#
#                            Vehicle_Class Vehicle_Category Vehicle_Type  \
# 48751                    ADAPTED VEHICLE           Others       Others
# 48752               AGRICULTURAL TRACTOR           Others       Others
# ...

# %%
df.loc[(df["Month_Name"] == "jul") &
       (df["Year"].isin([2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0,2021.0,2022.0,2023.0,2024.0])),"State"] = "Andaman & Nicobar Island"

# %%
df[(df["Month_Name"] == "aug") ]
# Out:
#          Year Month_Name      Date                     State  \
# 56734  2014.0        aug  8/1/2014                       NaN
# 56735  2014.0        aug  8/1/2014                       NaN
# 56736  2014.0        aug  8/1/2014                       NaN
# 56737  2014.0        aug  8/1/2014                       NaN
# 56738  2014.0        aug  8/1/2014                       NaN
# ...       ...        ...       ...                       ...
# 64625  2023.0        aug  8/1/2023  Andaman & Nicobar Island
# 64626  2023.0        aug  8/1/2023  Andaman & Nicobar Island
# 64627  2023.0        aug  8/1/2023  Andaman & Nicobar Island
# 64628  2023.0        aug  8/1/2023  Andaman & Nicobar Island
# 64629  2023.0        aug  8/1/2023  Andaman & Nicobar Island
#
#                            Vehicle_Class Vehicle_Category Vehicle_Type  \
# 56734                    ADAPTED VEHICLE           Others       Others
# 56735               AGRICULTURAL TRACTOR           Others       Others
# ...

# %%
df.loc[(df["Month_Name"] == "aug") &
       (df["Year"].isin([2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0,2021.0,2022.0,2023.0,2024.0])),"State"] = "Andaman & Nicobar Island"

# %%
df[(df["Month_Name"] == "sep") ]
# Out:
#          Year Month_Name      Date                     State  \
# 64630  2014.0        sep  9/1/2014                       NaN
# 64631  2014.0        sep  9/1/2014                       NaN
# 64632  2014.0        sep  9/1/2014                       NaN
# 64633  2014.0        sep  9/1/2014                       NaN
# 64634  2014.0        sep  9/1/2014                       NaN
# ...       ...        ...       ...                       ...
# 72669  2023.0        sep  9/1/2023  Andaman & Nicobar Island
# 72670  2023.0        sep  9/1/2023  Andaman & Nicobar Island
# 72671  2023.0        sep  9/1/2023  Andaman & Nicobar Island
# 72672  2023.0        sep  9/1/2023  Andaman & Nicobar Island
# 72673  2023.0        sep  9/1/2023  Andaman & Nicobar Island
#
#                             Vehicle_Class Vehicle_Category Vehicle_Type  \
# 64630                AGRICULTURAL TRACTOR           Others       Others
# 64631                           AMBULANCE           Others       Others
# ...

# %%
df.loc[(df["Month_Name"] == "sep") &
       (df["Year"].isin([2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0,2021.0,2022.0,2023.0,2024.0])),"State"] = "Andaman & Nicobar Island"

# %%
df[(df["Month_Name"] == "oct") ]
# Out:
#          Year Month_Name       Date                     State  \
# 72674  2014.0        oct  10/1/2014                       NaN
# 72675  2014.0        oct  10/1/2014                       NaN
# 72676  2014.0        oct  10/1/2014                       NaN
# 72677  2014.0        oct  10/1/2014                       NaN
# 72678  2014.0        oct  10/1/2014                       NaN
# ...       ...        ...        ...                       ...
# 80686  2023.0        oct  10/1/2023  Andaman & Nicobar Island
# 80687  2023.0        oct  10/1/2023  Andaman & Nicobar Island
# 80688  2023.0        oct  10/1/2023  Andaman & Nicobar Island
# 80689  2023.0        oct  10/1/2023  Andaman & Nicobar Island
# 80690  2023.0        oct  10/1/2023  Andaman & Nicobar Island
#
#                            Vehicle_Class Vehicle_Category Vehicle_Type  \
# 72674                    ADAPTED VEHICLE           Others       Others
# 72675               AGRICULTURAL TRACTOR           Others       Others
# ...

# %%
df.loc[(df["Month_Name"] == "oct") &
       (df["Year"].isin([2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0,2021.0,2022.0,2023.0,2024.0])),"State"] = "Andaman & Nicobar Island"

# %%
df.isnull().sum()
# Out:
# Year                   0
# Month_Name             0
# Date                   0
# State                578
# Vehicle_Class          0
# Vehicle_Category       0
# Vehicle_Type           0
# EV_Sales_Quantity      0
# dtype: int64

# %%
df[(df["Month_Name"] == "nov") ]
# Out:
#          Year Month_Name       Date                     State  \
# 80691  2014.0        nov  11/1/2014                       NaN
# 80692  2014.0        nov  11/1/2014                       NaN
# 80693  2014.0        nov  11/1/2014                       NaN
# 80694  2014.0        nov  11/1/2014                       NaN
# 80695  2014.0        nov  11/1/2014                       NaN
# ...       ...        ...        ...                       ...
# 88764  2023.0        nov  11/1/2023  Andaman & Nicobar Island
# 88765  2023.0        nov  11/1/2023  Andaman & Nicobar Island
# 88766  2023.0        nov  11/1/2023  Andaman & Nicobar Island
# 88767  2023.0        nov  11/1/2023  Andaman & Nicobar Island
# 88768  2023.0        nov  11/1/2023  Andaman & Nicobar Island
#
#                            Vehicle_Class Vehicle_Category Vehicle_Type  \
# 80691               AGRICULTURAL TRACTOR           Others       Others
# 80692                          AMBULANCE           Others       Others
# ...

# %%
df.loc[(df["Month_Name"] == "nov") &
       (df["Year"].isin([2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0,2021.0,2022.0,2023.0,2024.0])),"State"] = "Andaman & Nicobar Island"

# %%
df[(df["Month_Name"] == "dec") ]
# Out:
#          Year Month_Name       Date                     State  \
# 88769  2014.0        dec  12/1/2014                       NaN
# 88770  2014.0        dec  12/1/2014                       NaN
# 88771  2014.0        dec  12/1/2014                       NaN
# 88772  2014.0        dec  12/1/2014                       NaN
# 88773  2014.0        dec  12/1/2014                       NaN
# ...       ...        ...        ...                       ...
# 96840  2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 96841  2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 96842  2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 96843  2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 96844  2023.0        dec  12/1/2023  Andaman & Nicobar Island
#
#                            Vehicle_Class Vehicle_Category Vehicle_Type  \
# 88769               AGRICULTURAL TRACTOR           Others       Others
# 88770                          AMBULANCE           Others       Others
# ...

# %%
df.loc[(df["Month_Name"] == "dec") &
       (df["Year"].isin([2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0,2021.0,2022.0,2023.0,2024.0])),"State"] = "Andaman & Nicobar Island"

# %%
df.isnull().sum()
# Out:
# Year                 0
# Month_Name           0
# Date                 0
# State                0
# Vehicle_Class        0
# Vehicle_Category     0
# Vehicle_Type         0
# EV_Sales_Quantity    0
# dtype: int64
